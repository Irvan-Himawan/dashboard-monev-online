# %%
from data_loader import load_data
import pandas as pd

df = load_data()

df.head()
# Out:
#           Timestamp Usia anda saat ini? Jenis kelamin  \
# 0  28/04/2025 09.00                  38     Perempuan
# 1  28/04/2025 09.10                  20     Perempuan
# 2  28/04/2025 09.20                  29     Laki-laki
# 3  28/04/2025 09.30                  36     Laki-laki
# 4  28/04/2025 09.40                  36     Laki-laki
#
#   Pendidikan terakhir anda Pekerjaan anda saat ini  \
# 0                  Diploma                 Bekerja
# 1                  Sarjana                 Bekerja
# 2                 Magister           Pencari kerja
# 3                  SMA/SMK           Pencari kerja
# 4                  SMA/SMK           Pencari kerja
#
#    Nama Program pelatihan yang anda ikuti Tanggal Pelatihan (Awal)  \
# 0    Basic Smart Farming System (Blended)               02/05/2025
# 1              Pembuatan Yoghurt (Online)               05/05/2025
# 2    Basic Smart Farming System (Blended)               02/05/2025
# ...
